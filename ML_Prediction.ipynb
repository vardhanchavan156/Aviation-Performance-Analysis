# %%
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Aviation_KPIs_Dataset.csv")

# %%
df.head()
# Out:
#   Flight Number Scheduled Departure Time Actual Departure Time  \
# 0         FL885      2024-05-20 11:51:21   2024-07-10 02:38:54
# 1         FL930      2024-01-23 06:56:23   2024-07-07 02:53:44
# 2         FL478      2024-05-30 09:18:39   2024-12-05 01:00:54
# 3         FL637      2024-08-15 05:21:47   2024-09-21 13:23:42
# 4         FL318      2024-07-25 15:29:58   2024-03-21 15:05:54
#
#    Delay (Minutes)  Aircraft Utilization (Hours/Day)  \
# 0               50                             12.36
# 1               27                             14.53
# 2              108                             10.73
# 3               64                             15.10
# 4               30                             13.46
#
#    Turnaround Time (Minutes)  Load Factor (%)  Fleet Availability (%)  \
# 0                        115            79.18                   96.24
# 1                         83            98.59                   80.49
# 2                         87            67.44                   97.90
# 3                         99            69.01                   80.17
# 4                        114            50.36                   82.23
#
#    Maintenance Downtime (Hours)  Fuel Efficiency (ASK)  Revenue (USD)  \
# 0                          9.21                   4.15       10953.75
# 1                          1.55                   3.93       31597.25
# 2                          2.06                   4.26       13700.27
# 3                          6.85                   4.13       39913.01
# 4                          7.30                   4.97       11531.48
#
#    Operating Cost (USD)  Net Profit Margin (%)  Ancillary Revenue (USD)  \
# 0              27847.59                  17.90                  1058.68
# 1               1564.41                   7.70                  2941.32
# 2              30494.88                   5.84                  1920.45
# 3              13444.09                  24.09                  3167.79
# 4              34668.98                   7.18                   619.80
#
#    Debt-to-Equity Ratio  Revenue per ASK  Cost per ASK  Profit (USD)
# 0                  2.46          2639.46       6710.26     -16893.84
# 1                  2.89          8040.01        398.07      30032.84
# 2                  1.34          3216.03       7158.42     -16794.61
# 3                  0.60          9664.17       3255.23      26468.92
# 4                  0.84          2320.22       6975.65     -23137.50

# %%
df.columns
# Out:
# Index(['Flight Number', 'Scheduled Departure Time', 'Actual Departure Time',
#        'Delay (Minutes)', 'Aircraft Utilization (Hours/Day)',
#        'Turnaround Time (Minutes)', 'Load Factor (%)',
#        'Fleet Availability (%)', 'Maintenance Downtime (Hours)',
#        'Fuel Efficiency (ASK)', 'Revenue (USD)', 'Operating Cost (USD)',
#        'Net Profit Margin (%)', 'Ancillary Revenue (USD)',
#        'Debt-to-Equity Ratio', 'Revenue per ASK', 'Cost per ASK',
#        'Profit (USD)'],
#       dtype='object')

# %%
# Drop irrelevant columns
df.drop(columns=['Flight Number', 'Scheduled Departure Time', 'Actual Departure Time'], inplace=True)

# %%
# Handle missing values
df.fillna(df.median(), inplace=True)

# %%
# Feature and target split
x = df.drop(columns=['Profit (USD)'])  # Features
y = df['Profit (USD)']  # Target

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=43)

# %%
rf = RandomForestRegressor(
    n_estimators=100,
    max_depth=10,
    min_samples_split=5,
    min_samples_leaf=3,
    random_state=42
)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=10, min_samples_leaf=3, min_samples_split=5,
#                       random_state=42)

# %%
xgb = XGBRegressor(
    n_estimators = 100,
    max_depth = 6,
    learning_rate = 0.1,
    subsample = 0.8,
    colsample_bytree =0.8,
    reg_alpha = 0.1,
    reg_lambada = 1.0,
    random_state = 42
)

# %%
xgb = XGBRegressor(
    n_estimators=100,
    max_depth=6,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_alpha=0.1,
    reg_lambda=1.0,
    eval_metric='rmse',  # Move eval_metric here
    random_state=42
)

# %%
xgb.fit(
    x_train, y_train,
    eval_set=[(x_test, y_test)]
)
# Out:
# [0]	validation_0-rmse:17032.48318
# [1]	validation_0-rmse:15414.52016
# [2]	validation_0-rmse:13904.40443
# [3]	validation_0-rmse:12543.85086
# [4]	validation_0-rmse:11370.61128
# [5]	validation_0-rmse:10260.05275
# [6]	validation_0-rmse:9258.95729
# [7]	validation_0-rmse:8357.20990
# [8]	validation_0-rmse:7541.29486
# [9]	validation_0-rmse:7214.42756
# [10]	validation_0-rmse:6512.09251
# [11]	validation_0-rmse:5901.49971
# [12]	validation_0-rmse:5327.69708
# [13]	validation_0-rmse:4828.40678
# [14]	validation_0-rmse:4362.07781
# [15]	validation_0-rmse:3941.21972
# [16]	validation_0-rmse:3561.90730
# [17]	validation_0-rmse:3426.05475
# [18]	validation_0-rmse:3117.26856
# [19]	validation_0-rmse:2831.85499
# [20]	validation_0-rmse:2576.30927
# [21]	validation_0-rmse:2333.30285
# [22]	validation_0-rmse:2114.76027
# [23]	validation_0-rmse:1928.80358
# [24]	validation_0-rmse:1751.52938
# [25]	validation_0-rmse:1592.86076
# [26]	validation_0-rmse:1454.79072
# [27]	validation_0-rmse:1326.55483
# [28]	validation_0-rmse:1213.37299
# [29]	validation_0-rmse:1109.65680
# [30]	validation_0-rmse:1016.21896
# [31]	validation_0-rmse:933.00689
# [32]	validation_0-rmse:862.35472
# [33]	validation_0-rmse:796.39644
# [34]	validation_0-rmse:739.09583
# [35]	validation_0-rmse:687.42776
# [36]	validation_0-rmse:640.77881
# [37]	validation_0-rmse:601.83145
# [38]	validation_0-rmse:565.67161
# [39]	validation_0-rmse:535.94025
# [40]	validation_0-rmse:508.47114
# [41]	validation_0-rmse:483.94618
# [42]	validation_0-rmse:473.73433
# [43]	validation_0-rmse:454.19959
# [44]	validation_0-rmse:436.35081
# [45]	validation_0-rmse:421.42594
# [46]	validation_0-rmse:407.82544
# [47]	validation_0-rmse:396.57631
# [48]	validation_0-rmse:386.36201
# [49]	validation_0-rmse:377.72674
# [50]	validation_0-rmse:369.79128
# [51]	validation_0-rmse:363.37484
# [52]	validation_0-rmse:357.41564
# [53]	validation_0-rmse:352.32415
# [54]	validation_0-rmse:347.88411
# [55]	validation_0-rmse:343.90828
# [56]	validation_0-rmse:340.50506
# [57]	validation_0-rmse:337.44706
# [58]	validation_0-rmse:334.46609
# [59]	validation_0-rmse:331.86590
# [60]	validation_0-rmse:329.30400
# [61]	validation_0-rmse:326.92335
# [62]	validation_0-rmse:324.95617
# [63]	validation_0-rmse:323.21766
# [64]	validation_0-rmse:320.86691
# [65]	validation_0-rmse:319.95869
# [66]	validation_0-rmse:317.82844
# [67]	validation_0-rmse:316.77983
# [68]	validation_0-rmse:314.81588
# [69]	validation_0-rmse:313.50525
# [70]	validation_0-rmse:312.56939
# [71]	validation_0-rmse:311.39547
# [72]	validation_0-rmse:310.03539
# [73]	validation_0-rmse:309.15907
# [74]	validation_0-rmse:308.46316
# [75]	validation_0-rmse:307.22507
# [76]	validation_0-rmse:306.58762
# [77]	validation_0-rmse:305.71859
# [78]	validation_0-rmse:304.97177
# [79]	validation_0-rmse:303.72725
# [80]	validation_0-rmse:302.78684
# [81]	validation_0-rmse:301.96491
# [82]	validation_0-rmse:301.21511
# [83]	validation_0-rmse:300.90477
# [84]	validation_0-rmse:300.51756
# [85]	validation_0-rmse:299.82468
# [86]	validation_0-rmse:299.46128
# [87]	validation_0-rmse:299.13100
# [88]	validation_0-rmse:297.26297
# [89]	validation_0-rmse:296.84112
# [90]	validation_0-rmse:296.34695
# [91]	validation_0-rmse:295.58241
# [92]	validation_0-rmse:295.51076
# [93]	validation_0-rmse:295.01771
# [94]	validation_0-rmse:294.50564
# [95]	validation_0-rmse:293.70648
# [96]	validation_0-rmse:292.95144
# [97]	validation_0-rmse:291.78633
# [98]	validation_0-rmse:291.47454
# [99]	validation_0-rmse:291.02227
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric='rmse', feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# Predictions
rf_preds = rf.predict(x_test)
xgb_preds = xgb.predict(x_test)

# %%
# Metrics
for name, preds in zip(["Random Forest", "XGBoost"], [rf_preds, xgb_preds]):
    print(f"{name} Performance:")
    print(f"MAE: {mean_absolute_error(y_test, preds):.2f}")
    print(f"RMSE: {np.sqrt(mean_squared_error(y_test, preds)):.2f}")
    print(f"R2 Score: {r2_score(y_test, preds):.4f}\n")
# Out:
# Random Forest Performance:
# MAE: 196.48
# RMSE: 252.35
# R2 Score: 0.9998
#
# XGBoost Performance:
# MAE: 226.88
# RMSE: 291.02
# R2 Score: 0.9997

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Models
models = {"Random Forest": rf, "XGBoost": xgb}

# Evaluation
for name, model in models.items():
    # Predictions
    train_preds = model.predict(x_train)
    test_preds = model.predict(x_test)

    # Training Metrics
    train_mae = mean_absolute_error(y_train, train_preds)
    train_rmse = np.sqrt(mean_squared_error(y_train, train_preds))
    train_r2 = r2_score(y_train, train_preds)

    # Testing Metrics
    test_mae = mean_absolute_error(y_test, test_preds)
    test_rmse = np.sqrt(mean_squared_error(y_test, test_preds))
    test_r2 = r2_score(y_test, test_preds)

    print(f"\n{name} Performance:")
    print(f"Training -> MAE: {train_mae:.2f}, RMSE: {train_rmse:.2f}, R2: {train_r2:.4f}")
    print(f"Testing  -> MAE: {test_mae:.2f}, RMSE: {test_rmse:.2f}, R2: {test_r2:.4f}")

    # Overfitting Check
    if train_r2 > 0.90 and test_r2 < 0.75:
        print(f" {name} might be **overfitting**! Consider regularization or reducing complexity.")
    elif train_r2 < 0.60 and test_r2 < 0.60:
        print(f" {name} might be **underfitting**! Consider increasing model complexity.")
    else:
        print(f" {name} seems well-balanced.")
# Out:
# Random Forest Performance:
# Training -> MAE: 182.88, RMSE: 234.67, R2: 0.9998
# Testing  -> MAE: 196.48, RMSE: 252.35, R2: 0.9998
#  Random Forest seems well-balanced.
#
# XGBoost Performance:
# Training -> MAE: 217.24, RMSE: 278.68, R2: 0.9998
# Testing  -> MAE: 226.88, RMSE: 291.02, R2: 0.9997
#  XGBoost seems well-balanced.
